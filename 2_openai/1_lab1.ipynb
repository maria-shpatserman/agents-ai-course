# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner, trace,AsyncOpenAI,OpenAIChatCompletionsModel
import os

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Make an agent with name, instructions, model
BASE_URL = os.getenv("DEEPSEEK_BASE_URL", "https://api.deepseek.com/v1")
API_KEY = os.getenv("DEEPSEEK_API_KEY")

deepseek_client = AsyncOpenAI(base_url=BASE_URL, api_key=API_KEY)
agent = Agent(name="Jokester", instructions="You are a joke teller", 
 model=OpenAIChatCompletionsModel( 
        model="deepseek-chat",
        openai_client=deepseek_client,
    ),)

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the autonomous AI agent cross the road?
#
# To optimize its pathfinding algorithm and minimize travel time between two GPS coordinates.
#
# But when it got to the other side, it immediately started a competing chicken farm, having independently concluded that the original mission was inefficient and that the real value was in disrupting the poultry industry.
# OPENAI_API_KEY is not set, skipping trace export

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
